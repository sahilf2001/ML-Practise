# %%
# highest number in lower and middle quarter are lower quartile and middle quartile respectively
# lowest number in the upper quarter is the upper quartile

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Boston.csv')
df.head()
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# crim          False
# zn            False
# indus         False
# chas          False
# nox           False
# rm            False
# age           False
# dis           False
# rad           False
# tax           False
# ptratio       False
# black         False
# lstat         False
# medv          False
# dtype: bool

# %%
sns.boxplot(x=df['dis'])

# %%
sns.boxplot(x=df['zn'])

# %%
sns.boxplot(x=df['indus'])

# %%
sns.boxplot(x=df['age'])

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
# scatter plot between two variables indus and tax
fig,ax = plt.subplots(figsize=(16,8))
ax.scatter(df['indus'],df['tax'])
ax.set_xlabel('Proportion of non-retail businesses acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %% [markdown]
# # Z-score

# %%
from scipy import stats
z = np.abs(stats.zscore(df))
z
# Out:
# array([[1.72863116, 0.41978194, 0.28482986, ..., 0.44105193, 1.0755623 ,
#         0.15968566],
#        [1.72178509, 0.41733926, 0.48772236, ..., 0.44105193, 0.49243937,
#         0.10152429],
#        [1.71493903, 0.41734159, 0.48772236, ..., 0.39642699, 1.2087274 ,
#         1.32424667],
#        ...,
#        [1.71493903, 0.41344658, 0.48772236, ..., 0.44105193, 0.98304761,
#         0.14880191],
#        [1.72178509, 0.40776407, 0.48772236, ..., 0.4032249 , 0.86530163,
#         0.0579893 ],
#        [1.72863116, 0.41500016, 0.48772236, ..., 0.44105193, 0.66905833,
#         1.15724782]])

# %%
threshold = 3 # identifying outliers
np.where(z>threshold)
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#         200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#         220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#         277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#         357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#         380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#         416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#         437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64),
#  array([ 2,  2,  2, 12, 13,  4,  4,  4,  4,  4,  4,  4,  2,  2,  2,  2,  2,
#          2,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  6,  4,  4,  2,  6,
#          6,  4,  4,  4,  4,  4,  4,  2,  4,  2,  2,  8,  8,  2,  8,  8,  8,
#          4,  4,  4,  4,  4,  6,  6,  6,  4,  4,  4, 13,  6, 13,  1,  1,  1,
#          1,  6,  1, 12, 12, 12, 13,  1, 13, 12, 12,  1, 12, 12, 12, 12, 12,
# ...

# %%
z[55][2]
# Out:
# 3.375038763517294

# %% [markdown]
# # Cleaning Data by Removing Outliers

# %%
df_no_outlier = df[(z<3).all(axis=1)]
df_no_outlier
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df_no_outlier.drop('Unnamed: 0',axis=1,inplace=True)
df_no_outlier
# Out:
# C:\Users\SAHIL\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# ...

# %% [markdown]
# # Finding Outliers Using IQR

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3 - q1
IQR
# Out:
# Unnamed: 0    252.500000
# crim            3.595037
# zn             12.500000
# indus          12.910000
# chas            0.000000
# nox             0.175000
# rm              0.738000
# age            49.050000
# dis             3.088250
# rad            20.000000
# tax           387.000000
# ptratio         2.800000
# black          20.847500
# lstat          10.005000
# medv            7.975000
# dtype: float64

# %%
boston_IQR_Outlier = df[~((df<(q1 - 1.5 * IQR))|(df>(q3 + 1.5 * IQR))).any(axis=1)]
boston_IQR_Outlier
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...
